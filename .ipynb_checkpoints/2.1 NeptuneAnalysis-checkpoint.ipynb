# %% [markdown]
# # Setting-Get Data

# %%
import neptune.new as neptune
import numpy as np
API_TOKEN = 'eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI4Njg5NjEzOC1mYWVjLTQ4NGUtOWY0NS1kZDIwM2M3NjVhN2IifQ=='

# %%
project = neptune.get_project(name='joao.d.oliveira/Computer-Vision', api_token=API_TOKEN)
runs_table_df = project.fetch_runs_table().to_pandas()
colsKeep = ['sys/id', 'parameters/run_name', 'parameters/learning_rate', 'parameters/loss_function', 
            'parameters/optimizer', 'parameters/momentum', 'metrics/test/MAE', 'metrics/test/MAE-Smooth',
            'metrics/test/MSE', 'metrics/train/loss', 'parameters/n_epochs', 'parameters/batch_size',
            'duration', 'sys/creation_time']

runs_table_df = runs_table_df[colsKeep]
ids = runs_table_df['sys/id'].values
runs_table_df = runs_table_df.set_index('sys/id')

# %%
runs_table_df = runs_table_df.rename(columns={'parameters/run_name': 'run_name',
                                              'parameters/learning_rate':'LR',
                                              'parameters/loss_function':'loss_function',
                                              'parameters/optimizer':'optimizer',
                                              'parameters/momentum': 'momentum',
                                              'metrics/test/MAE': 'result_MAE',
                                              'metrics/test/MAE-Smooth':'result_MAE-Smooth',
                                              'metrics/test/MSE': 'result_MSE',
                                              'metrics/train/loss':'train_loss',
                                              'parameters/n_epochs':'n_epochs',
                                              'parameters/batch_size':'batch',
                                              'sys/creation_time':'creation_time'})

runs_table_df = runs_table_df.replace({'loss_function': {0:'MAE', 1:'MAE-Smooth', 2:'MSE'}})
runs_table_df = runs_table_df.replace({'optimizer': {0:'Adam', 1:'SGD'}})
runs_table_df['model'] = list(runs_table_df.run_name.apply(lambda x:x[:6]))
#runs_table_df['name_rum'] = list(runs_table_df.run_name.apply(lambda x:x[:6]))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
#runs_table_df['name'] = le.fit_transform(list(runs_table_df.run_name.apply(lambda x:x[6:])))
#runs_table_df['name'] = list(runs_table_df.run_name.apply(lambda x:x[6:]))
runs_table_df['name'] = runs_table_df['run_name']

runs_table_df = runs_table_df.sort_values('name')

df_optm = [runs_table_df.loc[runs_table_df.optimizer == op] for op in runs_table_df.optimizer.unique()]
df_loss = [runs_table_df.loc[runs_table_df.loss_function == lo] for lo in runs_table_df.loss_function.unique()]
df_LR = [runs_table_df.loc[runs_table_df.LR == lr] for lr in runs_table_df.LR.unique()]
df_model = [runs_table_df.loc[runs_table_df.model == m] for m in runs_table_df.model.unique()]

dfs = [df_optm, df_loss, df_LR, df_model]
metrics = ['MSE', 'MAE-Smooth', 'MAE']
divisions = ['Optimizers', 'Loss-Functions', 'LearningRates', 'Model']
name_processing = ['Opti', 'Loss', 'LR', 'v1.']
name_division = [runs_table_df.optimizer.unique(),
                 runs_table_df.loss_function.unique(),
                 runs_table_df.LR.unique(),
                 runs_table_df.model.unique()]

for d, df in enumerate(dfs):
    for f in range(len(df)):
        pnames = df[f].name.apply(lambda x:"-".join([a for a in x.split('-') if (name_processing[d] not in a) and ('Mom' not in a)]))
        #pnames = le.fit_transform(pnames)
        df[f].name = pnames
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/cv-nd/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
import pandas as pd
dfSummaryMeans = pd.DataFrame(index=['MAE', 'MAE-Smooth', 'MSE'], columns=[i for c in name_division for i in c])
dfSummaryMSE = pd.DataFrame(index=range(len(ids)))
dfSummaryMAE_Smooth = pd.DataFrame(index=range(len(ids)))
dfSummaryMAE = pd.DataFrame(index=range(len(ids)))

for i, division in enumerate(divisions):
    for d in range(len(dfs[i])):
        metric = 'MSE'
        df_n = pd.DataFrame(dfs[i][d][f'result_{metric}'].values , columns=[name_division[i][d]])
        dfSummaryMSE=pd.merge(dfSummaryMSE, df_n, how='outer', left_index=True, right_index=True)

        metric = 'MAE-Smooth'
        df_n = pd.DataFrame(dfs[i][d][f'result_{metric}'].values , columns=[name_division[i][d]])
        dfSummaryMAE_Smooth=pd.merge(dfSummaryMAE_Smooth, df_n, how='outer', left_index=True, right_index=True)

        metric = 'MAE'
        df_n = pd.DataFrame(dfs[i][d][f'result_{metric}'].values , columns=[name_division[i][d]])
        dfSummaryMAE=pd.merge(dfSummaryMAE, df_n, how='outer', left_index=True, right_index=True)        
        for m in range(len(metrics)): 
            v = round(np.mean(dfs[i][d][f'result_{metrics[m]}']), 5)
            dfSummaryMeans.loc[metrics[m], name_division[i][d]] = v

dfSummaryMSE = dfSummaryMSE.dropna(how="all")
dfSummaryMAE_Smooth = dfSummaryMAE_Smooth.dropna(how="all")
dfSummaryMAE = dfSummaryMAE.dropna(how="all")

# %% [markdown]
# ## Get full training-loss

# %%
for i in ids[1:]:
    run = neptune.init(project='joao.d.oliveira/Computer-Vision', run=i, mode="read-only", api_token=API_TOKEN)
    runs_table_df.loc[i, 'metrics/train/loss'] = ";".join(map(str, list(run['metrics/train/loss'].fetch_values().value)))
# Out:
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-486
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-485
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-484
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-483
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-482
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-481
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-480
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-479
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-478
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-477
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-476
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-475
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-474
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-473
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-472
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-471
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-470
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-469
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-468
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-467
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-466
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-465
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-464
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-463
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-462
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-461
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-460
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-459
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-458
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-457
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-456
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-455
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-454
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-453
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-452
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-451
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-450
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-449
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-448
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-447
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-446
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-445
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-444
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-443
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-442
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-441
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-440
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-439
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-438
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-437
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-436
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-435
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-434
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-433
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-432
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-431
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-430
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-429
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-428
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-427
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-426
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-425
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-424
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-423
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-422
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-421
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-420
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-419
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-418
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-417
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-416
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-415
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-414
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-413
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-412
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-411
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-410
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-409
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-408
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-407
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-406
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-405
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-404
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-403
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-402
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-398
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-396
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-394
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-392
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-390
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-388
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-386
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-384
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-382
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-380
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-378
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-376
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-374
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-372
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-370
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-368
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-366
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-364
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-362
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-360
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-358
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-356
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-354
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-352
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-349
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-347
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-344
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-342
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-340
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-338
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-336
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-334
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-332
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-330
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-328
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-326
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-324
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-322
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-320
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-318
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-306
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-305
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-304
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-303
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-302
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-301
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-300
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-299
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-298
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-297
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-296
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-295
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-294
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-293
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-292
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-291
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-290
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-289
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-288
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-287
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-286
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-285
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-284
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-283
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-282
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-281
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-280
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-279
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-278
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-277
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-276
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-275
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-274
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-273
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-272
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-271
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-270
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-269
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-268
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-267
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-266
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-265
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-264
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-263
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-262
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-261
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-260
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-259
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-258
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-257
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-256
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-255
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-254
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-253
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-252
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-251
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-250
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-249
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-248
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-247
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-246
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-245
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-244
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-243
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-242
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-241
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-240
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-239
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-238
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-237
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-236
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-235
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-234
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-233
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-232
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-231
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-230
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-229
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-228
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-227
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-226
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-225
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-224
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-223
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-222
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-221
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-220
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-219
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-218
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-217
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-216
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-215
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-214
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-213
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-212
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-211
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-210
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-209
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-208
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-207
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-206
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-205
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-204
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-203
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-202
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-201
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-200
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-199
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-198
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-197
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-195
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-194
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-193
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-192
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-191
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-190
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-189
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-188
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-187
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-186
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-185
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-182
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-181
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-178
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-177
# https://app.neptune.ai/joao.d.oliveira/Computer-Vision/e/COM-176

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Plot Analysis

# %% [markdown]
# ### All Combinations

# %%
#%matplotlib notebook
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")

sns.set(rc={"figure.figsize":(30, 20)})
fig, sub = plt.subplots(4, 3)
# Plot the responses for different events and regions
for d, df in enumerate(dfs):
    for i in range(len(metrics)):
        for f in range(len(df)):
            g = sns.lineplot(x="name",
                             y=df[f][f'result_{metrics[i]}'], data=df[f],
                             ax=sub[d, i])
            g.legend(labels=name_division[d])
            g.set_xlabel("Runs")
            g.set_ylabel(f"{metrics[i]} Results")
            g.set_title(f"{divisions[d]}-{metrics[i]}")
plt.savefig('allcombinations.png', dpi=300)
#plt.show(g)

# %% [markdown]
# ### Plot only one Measure / Metric

# %%
# %matplotlib notebook
import seaborn as sns

measure, metric = 0, 0
sns.set(rc={"figure.figsize":(10, 10)})

# Plot the responses for different events and regions
for f in range(len(dfs[measure])):
    g = sns.lineplot(x="name",
                     y=dfs[measure][f][f'result_{metrics[metric]}'],
                     data=dfs[measure][f])
    g.legend(labels=name_division[measure])
    g.set_xlabel("Runs")
    g.set_ylabel(f"{metrics[metric]} Results")
    g.set_title(f"{divisions[measure]}-{metrics[metric]}")
    
fig = g.get_figure()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ### Plot Summary

# %%
# %matplotlib inline

fig = plt.figure(figsize=(10,5))
for c in dfSummaryMeans.columns:
    x, y = list(range(len(dfSummaryMeans.index))), dfSummaryMeans[c].values
    plt.plot(x, y, label=c)

plt.legend(loc='upper center')
font_defined = {'family': 'serif', 'weight': 'normal', 'size': 16}
plt.xlabel("Metrics")
plt.ylabel("Results")
plt.text(0.0, 0.3, "MSE", font=font_defined)
plt.text(1, 0.10, 'MAE-Smooth', font=font_defined)
plt.text(1.9, 0.2, 'MAE', font=font_defined)
plt.tight_layout()
plt.show();

# %% [markdown]
# ### Plot OneMeasure-AllParameters

# %%
# %matplotlib inline

fig = plt.figure(figsize=(15,20))
ax = fig.add_subplot(3,1,1)
m = 'MSE'
for c in dfSummaryMSE.columns:
    x, y = list(range(len(dfSummaryMSE.index))), dfSummaryMSE[c].values
    plt.plot(x, y, label=c)

plt.legend(loc='upper right')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## TextAnalysis

# %%
for i, division in enumerate(divisions):
    print(f"Statistics from {division:<13} runs:")
    for d in range(len(dfs[i])):
        print(f"\t{name_division[i][d]:<10}", end=' -- ')
        for m in range(len(metrics)): 
            v = dfSummaryMeans.loc[metrics[m], name_division[i][d]]
            print(f"{metrics[m]:<7}: {v:<8}", end='; ')

        print(f"{round(np.mean(dfs[i][d]['duration']), 2)} seg")
# Out:
# Statistics from Optimizers    runs:
# 	Adam       -- MSE    : 0.09763 ; MAE-Smooth: 0.04827 ; MAE    : 0.21101 ; 388.97 seg
# 	SGD        -- MSE    : 0.19727 ; MAE-Smooth: 0.09524 ; MAE    : 0.31223 ; 336.24 seg
# Statistics from Loss-Functions runs:
# 	MAE        -- MSE    : 0.13495 ; MAE-Smooth: 0.06557 ; MAE    : 0.24393 ; 367.78 seg
# 	MAE-Smooth -- MSE    : 0.14721 ; MAE-Smooth: 0.07172 ; MAE    : 0.26519 ; 365.47 seg
# 	MSE        -- MSE    : 0.13883 ; MAE-Smooth: 0.06791 ; MAE    : 0.25405 ; 365.87 seg
# Statistics from LearningRates runs:
# 	0.0001     -- MSE    : 0.13709 ; MAE-Smooth: 0.06625 ; MAE    : 0.23811 ; 368.56 seg
# 	0.001      -- MSE    : 0.1653  ; MAE-Smooth: 0.0806  ; MAE    : 0.28147 ; 364.94 seg
# 	0.01       -- MSE    : 0.11861 ; MAE-Smooth: 0.05834 ; MAE    : 0.24359 ; 365.6 seg
# Statistics from Model         runs:
# 	v1.0.0     -- MSE    : 0.12476 ; MAE-Smooth: 0.06164 ; MAE    : 0.24453 ; 353.61 seg
# 	v1.1.0     -- MSE    : 0.1033  ; MAE-Smooth: 0.05123 ; MAE    : 0.22597 ; 517.18 seg
# 	v1.2.0     -- MSE    : 0.22613 ; MAE-Smooth: 0.10853 ; MAE    : 0.33618 ; 314.18 seg
# 	v1.3.0     -- MSE    : 0.10713 ; MAE-Smooth: 0.05219 ; MAE    : 0.21089 ; 280.51 seg

# %%
i = 0
for d in range(len(dfs[i])):
    print(f"{name_division[i][d]:<10}")
    for m in dfs[i][d].momentum.unique():
        print(f'{m:<15} - ', end='')
        for metric in metrics:
            v = round(np.mean(dfs[i][d].loc[dfs[i][d].momentum == m, f'result_{metric}']), 5)
            print(f"{metric:<7}: {v:<8}", end='; ')
        print()
# Out:
# Adam
# (0.8, 0.9)      - MSE    : 0.09574 ; MAE-Smooth: 0.04736 ; MAE    : 0.21005 ;
# (0.85, 0.95)    - MSE    : 0.0905  ; MAE-Smooth: 0.04492 ; MAE    : 0.2042  ;
# (0.85, 0.999)   - MSE    : 0.09801 ; MAE-Smooth: 0.04851 ; MAE    : 0.21038 ;
# (0.9, 0.999)    - MSE    : 0.10625 ; MAE-Smooth: 0.05229 ; MAE    : 0.21941 ;
# SGD
# 0.85            - MSE    : 0.19125 ; MAE-Smooth: 0.09306 ; MAE    : 0.30999 ;
# 0.8             - MSE    : 0.19654 ; MAE-Smooth: 0.09503 ; MAE    : 0.31222 ;
# 0.9             - MSE    : 0.20401 ; MAE-Smooth: 0.09762 ; MAE    : 0.3145  ;

# %%
for df in dfs[-1]:
    print(len(df))
# Out:
# 63
# 63
# 63
# 63
